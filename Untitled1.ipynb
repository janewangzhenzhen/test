# %%
import seaborn
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
% matplotlib inline

# %config InlineBackend.figure_format = 'retina'
plt.style.use('seaborn')

# %%
for i in range(3):
    print('Hello')
    
# 这段代码表达的是：将0～3（不包含3）范围内的每一个数字依次装入变量i内。在这个过程中，变量i被循环赋值3次，你可以理解成等同于：
# Out:
# Hello
# Hello
# Hello

# %%
i = 0
print('Hello')
i = 1
print('Hello')
i = 2
print('Hello')
# Out:
# Hello
# Hello
# Hello

# %%
train_loss = [0.0822, 0.0261, 0.0200, 0.0167, 0.0159, 0.0143, 0.0133, 0.0133, 0.0128, 0.0127]
valid_loss = [0.0287, 0.0221, 0.0190, 0.0188, 0.0181, 0.0180, 0.0182, 0.0180, 0.0200, 0.0188]
n_epochs = list(range(1, 11))
d1 = {'n_epochs':n_epochs, 'train_loss':train_loss, 'valid_loss':valid_loss}
df1 = pd.DataFrame(data=d1)

# %%
train_loss = [0.0762, 0.0204, 0.0169, 0.0146, 0.0131, 0.0134, 0.0126, 0.0115, 0.0114, 0.0109]
valid_loss = [0.0220, 0.0160, 0.0147, 0.0143, 0.0148, 0.0137, 0.0137, 0.0139, 0.0142, 0.0140]
n_epochs = list(range(1,11))
d2 = {'n_epochs':n_epochs, 'train_loss':train_loss, 'valid_loss':valid_loss}
df2 = pd.DataFrame(data=d2)

# %%
train_loss = [0.0588, 0.0173, 0.0149, 0.0133, 0.0123, 0.0105, 0.0108, 0.0089, 0.0093, 0.0096]
valid_loss = [0.0188, 0.0165, 0.0153, 0.0152, 0.0153, 0.0163, 0.0153, 0.0164, 0.0161, 0.0149]
n_epochs = list(range(1,11))
d3 = {'n_epochs':n_epochs, 'train_loss':train_loss, 'valid_loss':valid_loss}
df3 = pd.DataFrame(data=d3)

# %%
plt.figure(1, figsize=(15, 3))
plt.subplot(131)
plt.plot(df1['n_epochs'], df1['train_loss'], 'r')
plt.legend()
plt.plot(df1['n_epochs'], df1['valid_loss'], 'b')
plt.legend()
plt.xlabel('n_epochs')
plt.title('ResNet50 & Xception')

plt.subplot(132)
plt.plot(df2['n_epochs'], df2['train_loss'], 'r')
plt.legend()
plt.plot(df2['n_epochs'], df2['valid_loss'], 'b')
plt.legend()

plt.xlabel('n_epochs')
plt.title('InceptionV3 & Xception')

plt.subplot(133)
plt.plot(df3['n_epochs'], df3['train_loss'], 'r')
plt.legend()
plt.plot(df3['n_epochs'], df3['valid_loss'], 'b')
plt.legend()
plt.xlabel('n_epochs')
plt.title('Xception&InceptionV3&ResNet50')
# Out:
# Text(0.5,1,'Xception&InceptionV3&ResNet50')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
import keras
# Out:
# /Users/JaneWang/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# ?pd.DataFrame

# %%
import pandas as pd

# %%
import numpy as np

# %%
# ?np.array

# %%
for i in manifest:
    print(i)

# %%
for x, y in manifest:
    print(x)
    print(y)

# %%
for i in range(10):
    print('第'+ str(i+1) + '次循环的输出: '+str(i))
    print('--------------')
# Out:
# 第1次循环的输出: 0
# --------------
# 第2次循环的输出: 1
# --------------
# 第3次循环的输出: 2
# --------------
# 第4次循环的输出: 3
# --------------
# 第5次循环的输出: 4
# --------------
# 第6次循环的输出: 5
# --------------
# 第7次循环的输出: 6
# --------------
# 第8次循环的输出: 7
# --------------
# 第9次循环的输出: 8
# --------------
# 第10次循环的输出: 9
# --------------
